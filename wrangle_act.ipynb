# %% [markdown]
# # 项目：WeRateDogs数据清洗和分析

# %% [markdown]
# ## 目录
# <ul>
# <li><a href="#intro">简介</a></li>
# <li><a href="#gaher">收集</a></li>
# <li><a href="#assert">评估</a></li>
# <li><a href="#clean">清洗</a></li>
# <li><a href="#analysis">分析</a></li>
# <li><a href="#conclusions">结论</a></li>
# </ul>
#
#
# <a id='intro'></a>
# ## 简介
#
# 本次项目选取推特昵称为WeRateDogs的档案为数据集进行数据清洗分析和可视化。因为这份档案只包含基础信息，还需要另外收集相关数据，一起进行评估和清洗，得出结论。

# %% [markdown]
# <a id="gaher"></a>
# ## 收集

# %%
# 加载库
import pandas as pd
import numpy as np
import requests
import os
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
from datetime import datetime
# 这段代码可以使可视化不会出现中文乱码
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 收集三份数据：
#
# - twitter_archive_enhanced.csv  推特档案
# - tweet_json.txt 包含转发数(retweet_count)和喜欢数（favortite_count）
# - image_predicitions.tsv  图像预测文件,对推特中中的品种（或其他物体）进行预测的结果

# %%
# 读取数据
df_twitter = pd.read_csv('twitter-archive-enhanced.csv')

# %%
df_twitter.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
# 没有目录创建目录,从url中下载数据，存到image_predicitions.tsv这里
import os
folder_name = 'reviews'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
   
url = 'https://raw.githubusercontent.com/udacity/new-dand-advanced-china/master/%E6%95%B0%E6%8D%AE%E6%B8%85%E6%B4%97/WeRateDogs%E9%A1%B9%E7%9B%AE/image-predictions.tsv'
response = requests.get(url)
with open(os.path.join(folder_name,'image_predicitions.tsv'),mode='wb') as file:
        file.write(response.content)

# %%
# 读入数据
df_image = pd.read_csv('image_predicitions.tsv',sep='\t')

# %%
df_image.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
# tweet_json.txt逐行导入DataFrame
tweet_list=[]
with open('tweet_json.txt','r') as f:
    for row in f:
        json_dict = json.loads(row)
        to_append={
            'tweet_id':json_dict['id'],
            'retweet_count':json_dict['retweet_count'],
            'favorite_count':json_dict['favorite_count']
        }
        tweet_list.append(to_append)

   
df_tweet=pd.DataFrame(tweet_list,columns=['tweet_id','retweet_count','favorite_count'])

# %%
df_tweet.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8842           39492
# 1  892177421306343426           6480           33786
# 2  891815181378084864           4301           25445
# 3  891689557279858688           8925           42863
# 4  891327558926688256           9721           41016

# %% [markdown]
# <a id='assert'></a>
# ## 评估

# %%
df_twitter
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
# text 文本全部显示
pd.set_option('max_colwidth',200)

# %%
df_twitter.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
# 查重
df_twitter[df_twitter.tweet_id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
df_twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df_twitter['rating_numerator'].describe()
# Out:
# count    2356.000000
# mean       13.126486
# std        45.876648
# min         0.000000
# 25%        10.000000
# 50%        11.000000
# 75%        12.000000
# max      1776.000000
# Name: rating_numerator, dtype: float64

# %%
df_twitter.rating_numerator.sort_values(ascending=False)
# Out:
# 979     1776
# 313      960
# 189      666
# 188      420
# 2074     420
# 1120     204
# 290      182
# 902      165
# 1779     144
# 1634     143
# 1635     121
# 1228      99
# 1843      88
# 433       84
# 1254      80
# 695       75
# 340       75
# 1351      60
# 1202      50
# 1274      45
# 1433      44
# 763       27
# 1712      26
# 516       24
# 1663      20
# 55        17
# 285       15
# 291       15
# 83        14
# 866       14
#         ...
# 2183       3
# 1314       3
# 1928       3
# 765        3
# 2202       3
# 1692       3
# 1478       3
# 1898       3
# 1249       3
# 2305       3
# 2079       2
# 2326       2
# 2349       2
# 2237       2
# 2246       2
# 1920       2
# 1761       2
# 2310       2
# 1764       2
# 1940       1
# 2038       1
# 2091       1
# 1869       1
# 1446       1
# 605        1
# 2338       1
# 2261       1
# 2335       1
# 1016       0
# 315        0
# Name: rating_numerator, Length: 2356, dtype: int64

# %%
df_twitter[df_twitter['rating_numerator']<10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 45    883482846933004288                    NaN                  NaN
# 229   848212111729840128                    NaN                  NaN
# 315   835152434251116546                    NaN                  NaN
# 387   826598799820865537           8.265984e+17         4.196984e+09
# 462   817502432452313088                    NaN                  NaN
# 485   814578408554463233                    NaN                  NaN
# 599   798682547630837760                    NaN                  NaN
# 605   798576900688019456                    NaN                  NaN
# 730   781661882474196992                    NaN                  NaN
# 745   780092040432480260                    NaN                  NaN
# 764   777953400541634568                    NaN                  NaN
# 765   777885040357281792                    NaN                  NaN
# 784   775096608509886464                    NaN                  NaN
# ...

# %%
df_twitter['rating_denominator'].describe()
# Out:
# count    2356.000000
# mean       10.455433
# std         6.745237
# min         0.000000
# 25%        10.000000
# 50%        10.000000
# 75%        10.000000
# max       170.000000
# Name: rating_denominator, dtype: float64

# %%
df_twitter.rating_denominator.sort_values(ascending=False)
# Out:
# 1120    170
# 902     150
# 1634    130
# 1779    120
# 1635    110
# 1228     90
# 1254     80
# 1843     80
# 433      70
# 1274     50
# 1351     50
# 1202     50
# 1433     40
# 1598     20
# 1165     20
# 1663     16
# 342      15
# 1662     11
# 1068     11
# 784      11
# 800      10
# 778      10
# 777      10
# 776      10
# 779      10
# 780      10
# 799      10
# 775      10
# 781      10
# 782      10
#        ...
# 1556     10
# 1555     10
# 1554     10
# 1553     10
# 1552     10
# 1551     10
# 1550     10
# 1549     10
# 1548     10
# 1547     10
# 1562     10
# 0        10
# 1571     10
# 1577     10
# 1564     10
# 1565     10
# 1566     10
# 1567     10
# 1568     10
# 1569     10
# 1570     10
# 1563     10
# 1572     10
# 1573     10
# 1574     10
# 1575     10
# 1576     10
# 516       7
# 2335      2
# 313       0
# Name: rating_denominator, Length: 2356, dtype: int64

# %%
# 查看retweeted_status_id非空值
df_twitter[df_twitter['retweeted_status_id'].notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# 74    878316110768087041                    NaN                  NaN
# 78    877611172832227328                    NaN                  NaN
# 91    874434818259525634                    NaN                  NaN
# 95    873697596434513921                    NaN                  NaN
# 97    873337748698140672                    NaN                  NaN
# 101   872668790621863937                    NaN                  NaN
# 109   871166179821445120                    NaN                  NaN
# 118   869988702071779329                    NaN                  NaN
# ...

# %%
df_tweet
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           8842           39492
# 1     892177421306343426           6480           33786
# 2     891815181378084864           4301           25445
# 3     891689557279858688           8925           42863
# 4     891327558926688256           9721           41016
# 5     891087950875897856           3240           20548
# 6     890971913173991426           2142           12053
# 7     890729181411237888          19548           66596
# 8     890609185150312448           4403           28187
# 9     890240255349198849           7684           32467
# 10    890006608113172480           7584           31127
# 11    889880896479866881           5116           28208
# 12    889665388333682689           8502           38745
# 13    889638837579907072           4705           27633
# 14    889531135344209921           2309           15329
# 15    889278841981685760           5635           25712
# ...

# %%
# 查重
df_tweet[df_tweet.tweet_id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, retweet_count, favorite_count]
# Index: []

# %%
df_tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2352 entries, 0 to 2351
# Data columns (total 3 columns):
# tweet_id          2352 non-null int64
# retweet_count     2352 non-null int64
# favorite_count    2352 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %%
df_tweet.describe()
# Out:
#            tweet_id  retweet_count  favorite_count
# count  2.352000e+03    2352.000000     2352.000000
# mean   7.425913e+17    3134.932398     8109.198980
# std    6.846210e+16    5237.846296    11980.795669
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783949e+17     618.000000     1417.000000
# 50%    7.193536e+17    1456.500000     3596.500000
# 75%    7.991219e+17    3628.750000    10118.000000
# max    8.924206e+17   79116.000000   132318.000000

# %%
df_image
# Out:
#                 tweet_id  \
# 0     666020888022790149
# 1     666029285002620928
# 2     666033412701032449
# 3     666044226329800704
# 4     666049248165822465
# 5     666050758794694657
# 6     666051853826850816
# 7     666055525042405380
# 8     666057090499244032
# 9     666058600524156928
# 10    666063827256086533
# 11    666071193221509120
# 12    666073100786774016
# 13    666082916733198337
# 14    666094000022159362
# 15    666099513787052032
# 16    666102155909144576
# 17    666104133288665088
# 18    666268910803644416
# 19    666273097616637952
# 20    666287406224695296
# 21    666293911632134144
# 22    666337882303524864
# 23    666345417576210432
# 24    666353288456101888
# 25    666362758909284353
# 26    666373753744588802
# 27    666396247373291520
# 28    666407126856765440
# 29    666411507551481857
# ...                  ...
# 2045  886366144734445568
# 2046  886680336477933568
# 2047  886736880519319552
# 2048  886983233522544640
# ...

# %%
# 查重
df_image[df_image.tweet_id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %%
df_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# #### 质量
#
# **twitter_archive_enhanced表格**
# - retweeted_status_id含有转发数据
# - tweet_id是整数，不是字符串
# - rating_numerator分子中有低于10分的数据
# - rating_denominator分母有不等于10分的数据
# - name中有空值，且含a、an等错误
# - doggo	floofer	pupper	puppo有全空的
#
# **tweet_json表格**
# - tweet_id是整数，不是字符串
#
# **image_predicitions表格**
# - tweet_id是整数，不是字符串
#
# **清洁度**
#  - twitter_archive_enhanced表中狗狗的地位（stage）:doggo,pupper,puppo,floof(er)成为一列。
#  - 把twitter表和tweet变成一张表，两者的联系是tweet_id
#  - 删除twitter的无用列，只保留tweet_id,text,rating_numerator,rating_denominator, name，stage

# %% [markdown]
# <a id='clean'></a>
# ## 清洁

# %%
# 备份
df_twitter_clean = df_twitter.copy()
df_tweet_clean = df_tweet.copy()
df_image_clean = df_image.copy()

# %% [markdown]
# ### 缺失数据
#
#
#
#
# ##### 定义
# df_twitter_clean表中doggo	floofer	pupper	puppo有全空的数据，并且数据不太对，删除这些列
#
#
# ##### 代码

# %%
df_twitter_clean = df_twitter_clean.drop(['doggo', 'floofer', 'pupper', 'puppo'],axis=1)

# %% [markdown]
# ##### 测试

# %%
df_twitter_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
df_twitter_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 13 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 239.4+ KB

# %% [markdown]
# ### 整洁度
#
#
# ##### 定义
#
# 对twitter_archive_enhanced表新增一个变量stage，暂时以np.nan代替，后续会从text中提取
#
# ##### 代码

# %%
df_twitter_clean['stage'] = np.nan

# %% [markdown]
# ##### 测试

# %%
df_twitter_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
df_twitter_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# stage                         0 non-null float64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 257.8+ KB

# %% [markdown]
# ##### 定义
#
# 利用函数mege把df_twitter_clean和df_tweet_clean合成一张表
# ##### 代码

# %%
df_twitter_clean = pd.merge(df_twitter_clean,df_tweet_clean,on=['tweet_id'],how='left')

# %% [markdown]
# #### 测试

# %%
df_twitter_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %% [markdown]
# ##### 定义
#
# 删除df_twitter_clean的无用列，只保留tweet_id,text,retweeted_status_id,rating_numerator,rating_denominator, name，stage,retweet_count,favorite_count
#
# ##### 代码

# %%
df_twitter_clean = df_twitter_clean[['tweet_id','text','retweeted_status_id',
                                     'rating_numerator','rating_denominator','name','stage','retweet_count','favorite_count']]

# %% [markdown]
# #### 测试

# %%
df_twitter_clean.head()
# Out:
#              tweet_id  \
# 0  892420643555336193
# 1  892177421306343426
# 2  891815181378084864
# 3  891689557279858688
# 4  891327558926688256
#
#                                                                                                                                                                  text  \
# 0                                                       This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
# 1  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
# 2                   This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# 3                                                             This is Darla. She commenced a snooze mid meal. 13/10 happens to the best of us https://t.co/tD36da7qLQ
# ...

# %% [markdown]
# ### 质量
#
#
# ##### 定义
# 使用as.type()把tweet_id的数据类型修改为字符串。因为tweet表格已经合并到twitter表格里，因此只需对df_twitter_clean和df_image_clean进行操作即可。
#
# ##### 代码

# %%
df_twitter_clean.tweet_id.head()
# Out:
# 0    892420643555336193
# 1    892177421306343426
# 2    891815181378084864
# 3    891689557279858688
# 4    891327558926688256
# Name: tweet_id, dtype: int64

# %%
df_twitter_clean.tweet_id = df_twitter_clean.tweet_id.astype(str)

# %%
df_image_clean.tweet_id.head()
# Out:
# 0    666020888022790149
# 1    666029285002620928
# 2    666033412701032449
# 3    666044226329800704
# 4    666049248165822465
# Name: tweet_id, dtype: int64

# %%
df_image_clean.tweet_id = df_image_clean.tweet_id.astype(str)

# %% [markdown]
# #### 测试

# %%
df_twitter_clean.tweet_id.head()
# Out:
# 0    892420643555336193
# 1    892177421306343426
# 2    891815181378084864
# 3    891689557279858688
# 4    891327558926688256
# Name: tweet_id, dtype: object

# %%
df_image_clean.tweet_id.head()
# Out:
# 0    666020888022790149
# 1    666029285002620928
# 2    666033412701032449
# 3    666044226329800704
# 4    666049248165822465
# Name: tweet_id, dtype: object

# %% [markdown]
# ##### 定义
# 利用drop删除df_twitter_clean里retweeted_status_id的非空值，删除转发数据
#
# ##### 代码

# %%
df_twitter_clean = df_twitter_clean[df_twitter_clean.retweeted_status_id.isnull()]

# %% [markdown]
# #### 测试

# %%
sum(df_twitter_clean.retweeted_status_id.notnull())
# Out:
# 0

# %%
df_twitter_clean
# Out:
#                 tweet_id  \
# 0     892420643555336193
# 1     892177421306343426
# 2     891815181378084864
# 3     891689557279858688
# 4     891327558926688256
# 5     891087950875897856
# 6     890971913173991426
# 7     890729181411237888
# 8     890609185150312448
# 9     890240255349198849
# 10    890006608113172480
# 11    889880896479866881
# 12    889665388333682689
# 13    889638837579907072
# 14    889531135344209921
# 15    889278841981685760
# 16    888917238123831296
# 17    888804989199671297
# 18    888554962724278272
# 20    888078434458587136
# 21    887705289381826560
# 22    887517139158093824
# 23    887473957103951883
# 24    887343217045368832
# 25    887101392804085760
# 26    886983233522544640
# 27    886736880519319552
# 28    886680336477933568
# 29    886366144734445568
# 30    886267009285017600
# ...                  ...
# 2326  666411507551481857
# 2327  666407126856765440
# 2328  666396247373291520
# 2329  666373753744588802
# ...

# %% [markdown]
# ##### 定义
#
# 使用正则表达式和pandas的`str.extract`方法，从text中提取rating_numerator,rating_denominator
# ##### 代码

# %%
# 提取出的分子rating_numerator的,去除特别高的，把范围限定在11~16
df_twitter_clean.rating_numerator = df_twitter_clean.text.str.extract('(1[1-6]\.?\d*)/10', expand=False).values
# 分母rating_denominator为10
df_twitter_clean.rating_denominator = df_twitter_clean.text.str.extract('1[1-6]\.?\d*/(10)', expand=False).values

# %%
# 修改数据类型
df_twitter_clean.rating_numerator = df_twitter_clean.rating_numerator.astype(float)
df_twitter_clean.rating_denominator = df_twitter_clean.rating_denominator.astype(float)

# %% [markdown]
# #### 测试

# %%
df_twitter_clean.rating_numerator.value_counts()
# Out:
# 12.00    501
# 11.00    428
# 13.00    311
# 14.00     44
# 11.27      1
# 11.26      1
# 15.00      1
# 13.50      1
# Name: rating_numerator, dtype: int64

# %%
df_twitter_clean[df_twitter_clean.rating_denominator != 10]
# Out:
#                 tweet_id  \
# 113   870726314365509632
# 188   855862651834028034
# 189   855860136149123072
# 229   848212111729840128
# 232   847962785489326080
# 274   840698636975636481
# 275   840696689258311684
# 290   838150277551247360
# 315   835152434251116546
# 323   834089966724603904
# 335   832645525019123713
# 342   832088576586297345
# 368   828708714936930305
# 387   826598799820865537
# 433   820690176645140481
# 444   819238181065359361
# 505   812781120811126785
# 514   811627233043480576
# 516   810984652412424192
# 521   809920764300447744
# 572   801285448605831168
# 642   793210959003287553
# 678   789268448748703744
# 691   787322443945877504
# 695   786709082849828864
# 705   785639753186217984
# 707   785515384317313025
# 725   782722598790725632
# 730   781661882474196992
# 735   781163403222056960
# ...                  ...
# 2322  666430724426358785
# 2323  666428276349472768
# 2325  666418789513326592
# 2326  666411507551481857
# ...

# %%
df_twitter_clean.sample()
# Out:
#                tweet_id  \
# 377  828011680017821696
#
#                                                                                                                                                      text  \
# 377  Say hello to Brutus and Jersey. They think they're the same size. Best furiends furever. Both 11/10 would pet simultaneously https://t.co/rkhCFfDtxB
#
#      retweeted_status_id  rating_numerator  rating_denominator    name  stage  \
# 377                  NaN              11.0                10.0  Brutus    NaN
#
#      retweet_count  favorite_count
# 377         2441.0         11364.0

# %% [markdown]
# ##### 定义
#
# 使用正则表达式和pandas的`str.extract`方法，从text中提取name
# ##### 代码

# %%
df_twitter_clean.name = df_twitter_clean.text.str.extract('(?:This is|Meet|name is|Say hello to|named) ([A-Z][a-z]{2,12})', expand=False).values

# %% [markdown]
# #### 测试

# %%
df_twitter_clean.name
# Out:
# 0        Phineas
# 1          Tilly
# 2         Archie
# 3          Darla
# 4       Franklin
# 5            NaN
# 6            Jax
# 7            NaN
# 8           Zoey
# 9         Cassie
# 10          Koda
# 11         Bruno
# 12           NaN
# 13           Ted
# 14        Stuart
# 15        Oliver
# 16           Jim
# 17          Zeke
# 18       Ralphus
# 20        Gerald
# 21       Jeffrey
# 22           NaN
# 23        Canela
# 24           NaN
# 25           NaN
# 26          Maya
# 27        Mingus
# 28         Derek
# 29        Roscoe
# 30           NaN
#           ...
# 2326         NaN
# 2327         NaN
# 2328         NaN
# 2329         NaN
# 2330         NaN
# 2331         NaN
# 2332         NaN
# 2333         NaN
# 2334         NaN
# 2335         NaN
# 2336         NaN
# 2337         NaN
# 2338         NaN
# 2339         NaN
# 2340         NaN
# 2341         NaN
# 2342         NaN
# 2343         NaN
# 2344         NaN
# 2345         NaN
# 2346         NaN
# ...

# %% [markdown]
# ##### 定义
#
# 使用正则表达式和pandas的`str.extract`方法，从text中提取doggo,floof,pupper,puppo最后放入stage
# ##### 代码

# %%
# 提取地位
import re
for i in df_twitter_clean.index:
    stage_set = set(re.findall('(doggo|floofer|pupper|puppo)', df_twitter_clean.loc[i,'text']))
    if len(stage_set) > 0:
        stage_value = ', '.join(stage_set)
        df_twitter_clean.loc[i, 'stage'] = stage_value

# %%
df_twitter_clean.sample(15)
# Out:
#                 tweet_id  \
# 1999  672523490734551040
# 1419  698342080612007937
# 48    882992080364220416
# 844   766693177336135680
# 1034  745057283344719872
# 1825  676470639084101634
# 931   754120377874386944
# 1782  677687604918272002
# 7     890729181411237888
# 339   832273440279240704
# 1622  684914660081053696
# 1219  714631576617938945
# 1655  683391852557561860
# 2344  666071193221509120
# 1804  676946864479084545
#
#                                                                                                                                                             text  \
# 1999                              When she says she'll be ready in a minute but you've been waiting in the car for almost an hour. 10/10 https://t.co/EH0N3dFKUi
# 1419                This is Maximus. He's training for the tetherball world championship. The grind never stops. 11/10 (vid by @Amuly21) https://t.co/VmFfWMjNkp
# ...

# %%
df_twitter_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 9 columns):
# tweet_id               2175 non-null object
# text                   2175 non-null object
# retweeted_status_id    0 non-null float64
# rating_numerator       1288 non-null float64
# rating_denominator     1288 non-null float64
# name                   1399 non-null object
# stage                  364 non-null object
# retweet_count          2175 non-null float64
# favorite_count         2175 non-null float64
# dtypes: float64(5), object(4)
# memory usage: 249.9+ KB

# %% [markdown]
# ##### 定义
#
# 用merge方法把df_twitter_clean和df_image_clean合并在一起。去除不包含图片的。
#
# ##### 代码

# %%
df_twitter_clean = pd.merge(df_image_clean, df_twitter_clean,on='tweet_id',how='inner')

# %% [markdown]
# #### 测试

# %%
sum(df_twitter_clean.jpg_url.isnull())
# Out:
# 0

# %% [markdown]
# #### 保存数据

# %%
save_file_name = 'twitter_archive_master.csv'
df_twitter_clean.to_csv(save_file_name, encoding='utf-8',index=False)

# %% [markdown]
# <a id='analysis'></a>
# ## 分析

# %%
# 加载数据
df = pd.read_csv('twitter_archive_master.csv')

# %%
df.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog  \
# ...

# %% [markdown]
# #### 问题1： favorite_count点赞数和retweet_count转发数表现如何？

# %%
df.favorite_count.describe()
# Out:
# count      1994.000000
# mean       8923.133400
# std       12400.238808
# min          81.000000
# 25%        1972.250000
# 50%        4117.000000
# 75%       11275.500000
# max      132318.000000
# Name: favorite_count, dtype: float64

# %%
df.retweet_count.describe()
# Out:
# count     1994.000000
# mean      2770.021063
# std       4715.961325
# min         15.000000
# 25%        622.250000
# 50%       1348.500000
# 75%       3202.750000
# max      79116.000000
# Name: retweet_count, dtype: float64

# %% [markdown]
# #### 发现
#
# **favorite_count点赞数和retweet_count转发数不一致。**
# - favorite_count中位数大约是4117，retweet_count中位数大约是1348。
# - favorite_count最大值大约是132318，retweet_count中位数大约是79116。
# - 说明人们相对于转发，可能更偏爱点赞。

# %% [markdown]
# #### 问题2：狗狗rating评分主要集中在哪里？

# %% [markdown]
# df生成新的一列rating,用rating_numerator除以rating_denominator表示

# %%
df['rating'] = df_twitter_clean['rating_numerator']/ df_twitter_clean['rating_denominator']

# %%
df.sample(5)
# Out:
#                 tweet_id  \
# 703   684940049151070208
# 1378  766693177336135680
# 58    667090893657276420
# 970   706644897839910912
# 301   671511350426865664
#
#                                                                                       jpg_url  \
# 703                                           https://pbs.twimg.com/media/CYFlVUFWwAAEsWX.jpg
# 1378                                          https://pbs.twimg.com/media/CqPXYLLXEAAU2HC.jpg
# 58                                            https://pbs.twimg.com/media/CUH7oLuUsAELWib.jpg
# 970   https://pbs.twimg.com/ext_tw_video_thumb/706644797256241152/pu/img/NTqvmIUQExGmKFSR.jpg
# 301                                           https://pbs.twimg.com/media/CVGwAh-W4AAIHJz.jpg
#
#       img_num             p1   p1_conf  p1_dog                 p2   p2_conf  \
# 703         2  Border_collie  0.665578    True             collie  0.176846
# 1378        1       Doberman  0.948355    True             vizsla  0.015032
# ...

# %%
df.rating.hist()
plt.title('狗狗rating评分分布')
plt.xlabel('狗狗评分数')
plt.ylabel('数量')

# %% [markdown]
# #### 发现
#
# **狗狗的rating评分大部分集中在1.2,评分1.4已经比较少了**

# %% [markdown]
# #### 问题3：狗狗stage地位主要集中在哪里？

# %%
df.stage.value_counts()
# Out:
# pupper           221
# doggo             66
# puppo             26
# pupper, doggo      8
# floofer            3
# puppo, doggo       2
# Name: stage, dtype: int64

# %% [markdown]
# **狗狗stage地位主要集中在pupper。**

# %% [markdown]
# <a id='conclusions'></a>
# ## 结论

# %% [markdown]
# - favorite_count点赞数和retweet_count转发数不一致，相对于转发，人们更喜欢点赞。
# - 狗狗的rating评分大部分集中在1.2,评分1.4已经比较少了，1.5就更稀少了。
# - 狗狗stage地位主要集中在pupper。
